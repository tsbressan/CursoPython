# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import numpy as np

# %%
#nome do arquivo
file = "gra_10_9_2019.csv"

#ler arquivos csv com delimitador informado
dataset = pd.read_csv(file,sep=",")

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.columns
# Out:
# Index(['Exp', 'Site', 'Hole', 'Core', 'Type', 'Sect', 'A/W', 'Offset (cm)',
#        'Depth CSF-A (m)', 'Depth CSF-B (m)', 'Bulk density (GRA)',
#        'Timestamp (UTC)', 'Instrument', 'Instrument group', 'Text ID',
#        'Test No.', 'Comments'],
#       dtype='object')

# %% [markdown]
# Separa a quantidade de registros por Site - cria uma série(pandas.core.series.Series)
# Matriz unidirecional com label por coluna

# %%
quantidade = dataset['Site'].value_counts()

# %%
type(quantidade)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Exemplo de loop mostrando o label e o valor

# %%
labels = []
valor = []

# %%
for label, val in quantidade.iteritems():
    labels.append (label)
    valor.append (val)
    print (label, val)
# Out:
# U1513 31315
# U1512 30488
# U1514 19686
# U1516 17819
# U1515 3340

# %%
x = np.arange(len(labels))  # the label locations
width = 0.50  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, valor, width, label='Site')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Total number of records by site')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()

fig.savefig("teste.png")
plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:

explode = (0.1, 0.1, 0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(valor, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

ax1.legend(labels=labels,title="Legend:",
          loc="center left",
          bbox_to_anchor=(0.95, 0, 1, 1),prop={'size': 14})

ax1.set_title("Total number of records by site", fontsize=16)

plt.show()

# %%
#nome do arquivo
file1 = "teste_line.csv"

#ler arquivos csv com delimitador informado
dataset1 = pd.read_csv(file1,sep=";")

# %%
x1 = np.linspace(2.0, 4.0)
x2 = np.linspace(1.0, 14.0)

y1 = dataset1['pH_L']
y2 = dataset1['Fe_mg_L']

plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('Relação entre PH e Fe')
plt.ylabel('PH')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('Records')
plt.ylabel('Fe')
# Out:
# Text(0, 0.5, 'Fe')
